# %%
import numpy as np 
import matplotlib.pyplot as plt
import glob
import cv2
import pandas as pd
from skimage.feature import graycomatrix, graycoprops
from sklearn.preprocessing import LabelEncoder, StandardScaler
import pandas as pd
import seaborn as sns
import itertools
#import lightgbm as lgb
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical, set_random_seed

# %%
# Training Images
train_paths = glob.glob("training/**/*.jpg", recursive=True) # list of paths for all images in training folder
train_images = [cv2.imread(path, 0) for path in train_paths] # list of training images
train_labels = [path.split("\\")[1] for path in train_paths] # list of training image labels
# converting to numpy array
train_images = np.array(train_images)
train_labels = np.array(train_labels)

print("Shape of train_images: ", train_images.shape)
print("Shape of train_labels: ", train_labels.shape)
print("Number of Unique Labels: ", len(np.unique(train_labels)))
# Out:
# Shape of train_images:  (100, 150, 150)
# Shape of train_labels:  (100,)
# Number of Unique Labels:  4

# %%
# testing Images
test_paths = glob.glob("testing/**/*.jpg", recursive=True) # list of paths for all images in testing folder
test_images = [cv2.imread(path, 0) for path in test_paths] # list of testing images
test_labels = [path.split("\\")[1] for path in test_paths] # list of testing image labels
# converting to numpy array
test_images = np.array(test_images)
test_labels = np.array(test_labels)

print("Shape of test_images: ", test_images.shape)
print("Shape of test_labels: ", test_labels.shape)
print("Number of Unique Labels: ", len(np.unique(test_labels)))
# Out:
# Shape of test_images:  (40, 150, 150)
# Shape of test_labels:  (40,)
# Number of Unique Labels:  4

# %%
# Label Encoding Labels ['CR', 'CRP', 'CRT', 'CRTP'] -> [0 , 1, 2, 3]
le = LabelEncoder()
train_labels_enc = le.fit_transform(train_labels)
test_labels_enc = le.transform(test_labels)

# %%
x_train, y_train, x_test, y_test = train_images, train_labels_enc, test_images, test_labels_enc

# %%
def feature_extractor(image_list: np.ndarray, distances: list, angles: list):
    """ Extract Gray-Level Co-occerance Matrix (GLCM) Features 
        Parameters
        ----------
        image_list -> numpy array of images
        distances  -> list of distances (graycomatrix parameter) 
        angles     -> list of angles    (graycomatrix parameter)

        Returns
        ----------
        Pandas Dataframe of Image features of size I  * (D * A) where,
        I -> Number of images
        D -> Number of distances
        A -> Number of Angles
    """
    img_features_df = pd.DataFrame() # empty dataframe to append feature values
    
    # iterate through each image
    for img in image_list:
        df = pd.DataFrame() # empty dataframe store feature values for 'img' 
        params = list(itertools.product(distances, angles)) # possible pairs of distances and angles
        # glcm_features = ["energy", "correlation", "dissimilarity", "homogeinity", "contrast", "ASM"]

        # iterate for each distance and angle pair, calculate glcm and extract features
        for (d, ang) in params:
            GLCM = graycomatrix(img, [d], [np.deg2rad(ang)])
            df["Correlation_"+str(d)+"_"+str(ang)] = graycoprops(GLCM, "correlation")[0]
            df["Dissimilarity_"+str(d)+"_"+str(ang)] = graycoprops(GLCM, "dissimilarity")[0]
            df["Homogeneity_"+str(d)+"_"+str(ang)] = graycoprops(GLCM, "homogeneity")[0]
            df["Contrast_"+str(d)+"_"+str(ang)] = graycoprops(GLCM, "contrast")[0]
            df["ASM_"+str(d)+"_"+str(ang)] = graycoprops(GLCM, "ASM")[0]
            df["Energy_"+str(d)+"_"+str(ang)] = graycoprops(GLCM, "energy")[0]
        
        img_features_df =  pd.concat([img_features_df, df], ignore_index=True) # append extracted features

    return img_features_df

# %%
# Define GLCM Features parameters distances and angles
dists = [1, 2, 3, 4] # distances
angs  = [0, 45, 90, 135] # angles

# %%
x_features = feature_extractor(x_train, dists, angs) # generate glcm features for training data
scaler = StandardScaler()
x_features[x_features.columns] = scaler.fit_transform(x_features[x_features.columns]) # Scaling Features

# %%
print("Shape of GLCM Features for Training: ", x_features.shape)
x_features
# Out:
# Shape of GLCM Features for Training:  (100, 96)
#     Correlation_1_0  Dissimilarity_1_0  Homogeneity_1_0  Contrast_1_0  \
# 0         -1.126581          -1.335068         1.144631     -1.280457
# 1         -0.665040          -1.968588         2.166509     -1.655787
# 2         -1.010395          -0.389622        -0.146223     -0.598154
# 3         -1.735040          -1.400695         1.125321     -1.303081
# 4         -0.113717          -0.931235         0.577405     -0.992412
# ..              ...                ...              ...           ...
# 95        -0.168589           0.189275        -0.209046      0.154925
# 96         0.431054          -0.337762         0.195426     -0.374969
# 97         0.572204          -0.600051         0.376744     -0.671362
# 98         1.032656          -1.048495         0.754711     -1.087717
# 99         0.751996          -0.313672         0.045534     -0.451886
#
#      ASM_1_0  Energy_1_0  Correlation_1_45  Dissimilarity_1_45  \
# 0   1.818058    1.775963         -1.088562           -1.426842
# 1   3.410594    2.989806         -0.763916           -2.004108
# 2   0.136004    0.230035         -1.075026           -0.444658
# 3   2.298448    2.161880         -1.721253           -1.482198
# 4   0.420214    0.518278          0.014328           -1.035883
# ..       ...         ...               ...                 ...
# 95 -0.427896   -0.387953          0.002393            0.039173
# 96 -0.249796   -0.185286          0.484463           -0.353186
# 97 -0.117338   -0.039257          0.629580           -0.637498
# 98  0.173322    0.268676          1.068353           -1.054713
# 99 -0.459371   -0.424579          0.752363           -0.262715
#
#     Homogeneity_1_45  Contrast_1_45  ...  Homogeneity_4_90  Contrast_4_90  \
# 0           1.133758      -1.375570  ...          1.592706      -1.544461
# 1           2.251462      -1.724587  ...          2.635142      -1.704566
# 2          -0.156545      -0.651911  ...          0.498183      -0.945337
# 3           1.289317      -1.403063  ...          1.683606      -1.589969
# 4           0.555196      -1.098591  ...          0.179031      -0.976678
# ..               ...            ...  ...               ...            ...
# 95         -0.134869       0.002303  ...          0.121013      -0.271293
# 96          0.213178      -0.405994  ...          0.051755      -0.388803
# 97          0.078045      -0.711390  ...          0.280653      -0.489964
# 98          0.878742      -1.097206  ...          0.231344      -0.762290
# 99         -0.162986      -0.417684  ...         -0.188565      -0.115028
#
#     ASM_4_90  Energy_4_90  Correlation_4_135  Dissimilarity_4_135  \
# 0   2.266309     2.188434          -0.892900            -1.724300
# 1   3.625229     3.217478          -1.459676            -2.050449
# 2   0.439694     0.548052          -1.004450            -0.860150
# 3   2.852279     2.647528          -1.295723            -1.862470
# 4   0.369188     0.476161          -1.614874            -0.628506
# ..       ...          ...                ...                  ...
# 95 -0.302174    -0.254802           0.470548            -0.175602
# 96 -0.342744    -0.302080           0.719829            -0.298713
# 97 -0.187663    -0.123476           0.276475            -0.318703
# 98 -0.094255    -0.018555           0.481664            -0.506319
# 99 -0.539458    -0.537330           0.378564             0.091310
#
#     Homogeneity_4_135  Contrast_4_135  ASM_4_135  Energy_4_135
# 0            1.854367       -1.533657   2.287111      2.210126
# 1            2.747300       -1.727354   3.677146      3.261661
# 2            0.497431       -0.926507   0.460440      0.570207
# 3            2.005596       -1.614859   2.910238      2.697588
# 4           -0.242490       -0.813030   0.392587      0.501094
# ..                ...             ...        ...           ...
# 95          -0.036577       -0.245262  -0.315211     -0.270967
# 96           0.259661       -0.390755  -0.335895     -0.295153
# 97          -0.115368       -0.470591  -0.229953     -0.172369
# 98           0.037775       -0.674147  -0.145283     -0.076128
# 99          -0.324588       -0.075322  -0.544754     -0.545584
#
# [100 rows x 96 columns]

# %%
# Predict on Test data
# Extract features from test data and reshape, just like training data
test_features = feature_extractor(x_test, dists, angs)
test_features[test_features.columns] = scaler.transform(test_features[test_features.columns]) # Scaling Features

# %%
print("Shape of GLCM Features for Validation: ", test_features.shape)
# Out:
# Shape of GLCM Features for Validation:  (40, 96)

# %%
# ANN CONSTRUCTION
set_random_seed(14)
with tf.device("GPU"):
    in_dim = x_features.shape[1]
    ann = Sequential()
    ann.add(Dense(units=25, input_dim= in_dim, activation='relu'))
    ann.add(Dense(units=15, activation='relu'))
    ann.add(Dense(units=8, activation='relu'))
    ann.add(Dense(units=4, activation='softmax'))
    ann.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    # Fit training data
    ann.fit(x_features, to_categorical(train_labels_enc), epochs=150, batch_size=5)
# Evalute model on test data
scores = ann.evaluate(test_features, to_categorical(test_labels_enc))
print(f"\nloss: {round(scores[0], 3)} \t accuracy: {round(scores[1], 3)}") # Print loss and accuracy
# Out:
# Epoch 1/150
# 20/20 [==============================] - 1s 9ms/step - loss: 1.3273 - accuracy: 0.3500
# Epoch 2/150
# 20/20 [==============================] - 0s 9ms/step - loss: 1.1929 - accuracy: 0.4300
# Epoch 3/150
# 20/20 [==============================] - 0s 9ms/step - loss: 1.1098 - accuracy: 0.5000
# Epoch 4/150
# 20/20 [==============================] - 0s 10ms/step - loss: 1.0380 - accuracy: 0.6000
# Epoch 5/150
# 20/20 [==============================] - 0s 9ms/step - loss: 1.0018 - accuracy: 0.5600
# Epoch 6/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.9380 - accuracy: 0.6100
# Epoch 7/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.9023 - accuracy: 0.6000
# Epoch 8/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.8657 - accuracy: 0.5900
# Epoch 9/150
# 20/20 [==============================] - 0s 13ms/step - loss: 0.8245 - accuracy: 0.6000
# Epoch 10/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.8113 - accuracy: 0.6300
# Epoch 11/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.7858 - accuracy: 0.6100
# Epoch 12/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.7706 - accuracy: 0.5900
# Epoch 13/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.7393 - accuracy: 0.6200
# Epoch 14/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.7352 - accuracy: 0.6200
# Epoch 15/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.7212 - accuracy: 0.6400
# Epoch 16/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.7276 - accuracy: 0.6800
# Epoch 17/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6914 - accuracy: 0.6700
# Epoch 18/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6852 - accuracy: 0.7000
# Epoch 19/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6686 - accuracy: 0.7800
# Epoch 20/150
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6537 - accuracy: 0.7600
# Epoch 21/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6442 - accuracy: 0.7900
# Epoch 22/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6316 - accuracy: 0.7800
# Epoch 23/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6766 - accuracy: 0.7600
# Epoch 24/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6011 - accuracy: 0.8000
# Epoch 25/150
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6250 - accuracy: 0.7800
# Epoch 26/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5786 - accuracy: 0.7800
# Epoch 27/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5863 - accuracy: 0.7500
# Epoch 28/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6265 - accuracy: 0.8100
# Epoch 29/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5568 - accuracy: 0.8000
# Epoch 30/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5567 - accuracy: 0.8000
# Epoch 31/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5219 - accuracy: 0.8100
# Epoch 32/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5108 - accuracy: 0.8100
# Epoch 33/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5106 - accuracy: 0.8000
# Epoch 34/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.4994 - accuracy: 0.8100
# Epoch 35/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.4787 - accuracy: 0.8100
# Epoch 36/150
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4990 - accuracy: 0.8100
# Epoch 37/150
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4832 - accuracy: 0.8300
# Epoch 38/150
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4652 - accuracy: 0.8100
# Epoch 39/150
# 20/20 [==============================] - 0s 8ms/step - loss: 0.4385 - accuracy: 0.8200
# Epoch 40/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.4545 - accuracy: 0.8200
# Epoch 41/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.4350 - accuracy: 0.8300
# Epoch 42/150
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4203 - accuracy: 0.8400
# Epoch 43/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.4079 - accuracy: 0.8300
# Epoch 44/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.4163 - accuracy: 0.8400
# Epoch 45/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.3993 - accuracy: 0.8400
# Epoch 46/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.4267 - accuracy: 0.8300
# Epoch 47/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.4001 - accuracy: 0.8400
# Epoch 48/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.3643 - accuracy: 0.8800
# Epoch 49/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.3740 - accuracy: 0.8700
# Epoch 50/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.4013 - accuracy: 0.8400
# Epoch 51/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.4128 - accuracy: 0.8500
# Epoch 52/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.3598 - accuracy: 0.8800
# Epoch 53/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3704 - accuracy: 0.8500
# Epoch 54/150
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3716 - accuracy: 0.8800
# Epoch 55/150
# 20/20 [==============================] - 0s 8ms/step - loss: 0.3294 - accuracy: 0.8700
# Epoch 56/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.3415 - accuracy: 0.8800
# Epoch 57/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.3472 - accuracy: 0.8700
# Epoch 58/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.3087 - accuracy: 0.8800
# Epoch 59/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.3013 - accuracy: 0.8800
# Epoch 60/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.3244 - accuracy: 0.8800
# Epoch 61/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.2889 - accuracy: 0.9100
# Epoch 62/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.3080 - accuracy: 0.8900
# Epoch 63/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.3004 - accuracy: 0.8800
# Epoch 64/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.2857 - accuracy: 0.8700
# Epoch 65/150
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2616 - accuracy: 0.9100
# Epoch 66/150
# 20/20 [==============================] - 0s 8ms/step - loss: 0.2481 - accuracy: 0.9000
# Epoch 67/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.2528 - accuracy: 0.9200
# Epoch 68/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.2601 - accuracy: 0.9100
# Epoch 69/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.2604 - accuracy: 0.9100
# Epoch 70/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.2818 - accuracy: 0.9100
# Epoch 71/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.2905 - accuracy: 0.8900
# Epoch 72/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.2139 - accuracy: 0.9500
# Epoch 73/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.2170 - accuracy: 0.9400
# Epoch 74/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.2065 - accuracy: 0.9200
# Epoch 75/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.2200 - accuracy: 0.9200
# Epoch 76/150
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1884 - accuracy: 0.9600
# Epoch 77/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.2498 - accuracy: 0.9200
# Epoch 78/150
# 20/20 [==============================] - 0s 8ms/step - loss: 0.2246 - accuracy: 0.9300
# Epoch 79/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.2028 - accuracy: 0.9200
# Epoch 80/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1815 - accuracy: 0.9300
# Epoch 81/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1981 - accuracy: 0.9700
# Epoch 82/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.2026 - accuracy: 0.9300
# Epoch 83/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1929 - accuracy: 0.9500
# Epoch 84/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1857 - accuracy: 0.9400
# Epoch 85/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1913 - accuracy: 0.9500
# Epoch 86/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1770 - accuracy: 0.9400
# Epoch 87/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1718 - accuracy: 0.9600
# Epoch 88/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1523 - accuracy: 0.9400
# Epoch 89/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1534 - accuracy: 0.9500
# Epoch 90/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1612 - accuracy: 0.9600
# Epoch 91/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1496 - accuracy: 0.9500
# Epoch 92/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1610 - accuracy: 0.9600
# Epoch 93/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1699 - accuracy: 0.9300
# Epoch 94/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1597 - accuracy: 0.9400
# Epoch 95/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1214 - accuracy: 0.9700
# Epoch 96/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1329 - accuracy: 0.9700
# Epoch 97/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1246 - accuracy: 0.9800
# Epoch 98/150
# 20/20 [==============================] - 0s 8ms/step - loss: 0.1409 - accuracy: 0.9500
# Epoch 99/150
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1189 - accuracy: 0.9800
# Epoch 100/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1195 - accuracy: 0.9500
# Epoch 101/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1320 - accuracy: 0.9700
# Epoch 102/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1433 - accuracy: 0.9700
# Epoch 103/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1157 - accuracy: 0.9800
# Epoch 104/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1211 - accuracy: 0.9600
# Epoch 105/150
# 20/20 [==============================] - 0s 9ms/step - loss: 0.1263 - accuracy: 0.9500
# Epoch 106/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0991 - accuracy: 0.9800
# Epoch 107/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1033 - accuracy: 0.9800
# Epoch 108/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1126 - accuracy: 0.9800
# Epoch 109/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0971 - accuracy: 0.9700
# Epoch 110/150
# 20/20 [==============================] - 0s 13ms/step - loss: 0.1008 - accuracy: 0.9700
# Epoch 111/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1176 - accuracy: 0.9700
# Epoch 112/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1181 - accuracy: 0.9800
# Epoch 113/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1249 - accuracy: 0.9700
# Epoch 114/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.1278 - accuracy: 0.9600
# Epoch 115/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0971 - accuracy: 0.9600
# Epoch 116/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0972 - accuracy: 0.9800
# Epoch 117/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0891 - accuracy: 0.9700
# Epoch 118/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0857 - accuracy: 0.9700
# Epoch 119/150
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0897 - accuracy: 0.9600
# Epoch 120/150
# 20/20 [==============================] - 0s 15ms/step - loss: 0.1093 - accuracy: 0.9700
# Epoch 121/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0860 - accuracy: 0.9800
# Epoch 122/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0698 - accuracy: 0.9800
# Epoch 123/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0802 - accuracy: 0.9800
# Epoch 124/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0646 - accuracy: 0.9900
# Epoch 125/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0666 - accuracy: 0.9800
# Epoch 126/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0827 - accuracy: 0.9700
# Epoch 127/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.1101 - accuracy: 0.9600
# Epoch 128/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0717 - accuracy: 0.9800
# Epoch 129/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0774 - accuracy: 0.9800
# Epoch 130/150
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0657 - accuracy: 0.9700
# Epoch 131/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0604 - accuracy: 0.9800
# Epoch 132/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0742 - accuracy: 0.9800
# Epoch 133/150
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0849 - accuracy: 0.9800
# Epoch 134/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0698 - accuracy: 0.9700
# Epoch 135/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0688 - accuracy: 0.9800
# Epoch 136/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0741 - accuracy: 0.9800
# Epoch 137/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0856 - accuracy: 0.9700
# Epoch 138/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0589 - accuracy: 0.9900
# Epoch 139/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0631 - accuracy: 0.9700
# Epoch 140/150
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0498 - accuracy: 0.9800
# Epoch 141/150
# 20/20 [==============================] - 0s 15ms/step - loss: 0.0489 - accuracy: 0.9800
# Epoch 142/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0528 - accuracy: 0.9800
# Epoch 143/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0445 - accuracy: 0.9900
# Epoch 144/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0495 - accuracy: 0.9700
# Epoch 145/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0485 - accuracy: 0.9900
# Epoch 146/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0408 - accuracy: 1.0000
# Epoch 147/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0511 - accuracy: 0.9800
# Epoch 148/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0409 - accuracy: 0.9900
# Epoch 149/150
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0591 - accuracy: 0.9800
# Epoch 150/150
# 20/20 [==============================] - 0s 14ms/step - loss: 0.0478 - accuracy: 0.9800
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1284 - accuracy: 0.9750
#
# loss: 0.128 	 accuracy: 0.975

# %%
# Predict on train data
train_prediction = ann.predict(x_features)
train_prediction = np.argmax(train_prediction, axis=1) # get the class with the highest probability value
train_prediction = le.inverse_transform(train_prediction) # transform into labels

# Predict on test data
test_prediction = ann.predict(test_features)
test_prediction = np.argmax(test_prediction, axis=1) # get the class with the highest probability value
test_prediction = le.inverse_transform(test_prediction) # transform into labels
# Out:
# 4/4 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 8ms/step

# %%
# Classfication Report
print("Classification Report on Training Set")
print("-"*50)
print(classification_report(train_labels, train_prediction, digits=4))
print("Classification Report on Test Set")
print("-"*50)
print(classification_report(test_labels, test_prediction, digits=4))
# Out:
# Classification Report on Training Set
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#           CR     0.9615    1.0000    0.9804        25
#          CRP     1.0000    0.9600    0.9796        25
#          CRT     1.0000    1.0000    1.0000        25
#         CRTP     1.0000    1.0000    1.0000        25
#
#     accuracy                         0.9900       100
#    macro avg     0.9904    0.9900    0.9900       100
# weighted avg     0.9904    0.9900    0.9900       100
#
# Classification Report on Test Set
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#           CR     1.0000    1.0000    1.0000        10
#          CRP     1.0000    0.9000    0.9474        10
#          CRT     1.0000    1.0000    1.0000        10
#         CRTP     0.9091    1.0000    0.9524        10
#
#     accuracy                         0.9750        40
#    macro avg     0.9773    0.9750    0.9749        40
# weighted avg     0.9773    0.9750    0.9749        40

# %%
def gen_annotations(cf_matrix):
    """
    Generates Annotation for each cell in confusion matrix
    args:
        cf_matrix: confusion matrix (numpy array)
    """
    sums = np.sum(cf_matrix, axis=1, keepdims=True) # sum of each row
    cf_perc = 100*cf_matrix/sums # converting to percentage
    annot = np.empty_like(cf_matrix).astype(str) # creating a empty numpy array to store annotations for each cell
    # iterate through each cell and store the annotation
    rows, cols = cf_matrix.shape 
    for i in range(rows):
        for j in range(cols):
            val = cf_matrix[i, j]
            perc_val = cf_perc[i, j]
            if val == 0: 
                annot[i, j] = '0'
            else:
                sum_val = sums[i][0]
                annot[i, j] = "%.1f%%\n(%d/%d)" % (perc_val, val, sum_val)
    return annot

# %%
# Plot confusion matrix Training Set-1
cm = confusion_matrix(train_labels, train_prediction)
annot = gen_annotations(cm)
fig = sns.heatmap(cm, annot=annot, fmt='', cbar=False, linewidth=1,
            xticklabels=['CR', 'CRP', 'CRT', 'CRTP'],
            yticklabels=['CR', 'CRP', 'CRT', 'CRTP']).get_figure()

plt.xlabel('Predicted Class')
plt.ylabel('Actual Class')
plt.title('ANN Confusion Matrix for Train Set-1 Images')
plt.show()
fig.savefig("plots/ann/cfmatrix_ann_train_set_1.png", dpi=600)

# %%
# Plot confusion matrix Testing Set-1
cm = confusion_matrix(test_labels, test_prediction)
annot = gen_annotations(cm)
fig = sns.heatmap(cm, annot=annot, fmt='', cbar=False, linewidth=1,
            xticklabels=['CR', 'CRP', 'CRT', 'CRTP'],
            yticklabels=['CR', 'CRP', 'CRT', 'CRTP']).get_figure()

plt.xlabel('Predicted Class')
plt.ylabel('Actual Class')
plt.title('ANN Confusion Matrix for Test Set-1 Images')
plt.show()
fig.savefig("plots/ann/cfmatrix_ann_test_set_1.png", dpi=600)

# %% [markdown]
# ## Shap Analysis

# %%
import shap

# %%
# get shap values
shap_values = shap.KernelExplainer(ann.predict, x_features).shap_values(test_features)
# Out:
# 4/4 [==============================] - 0s 6ms/step
#   0%|          | 0/40 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 52ms/step
# 7000/7000 [==============================] - 38s 5ms/step
# 1/1 [==============================] - 0s 48ms/step
# 7000/7000 [==============================] - 38s 5ms/step
# 1/1 [==============================] - 0s 46ms/step
# 7000/7000 [==============================] - 38s 5ms/step
# 1/1 [==============================] - 0s 47ms/step
# 7000/7000 [==============================] - 38s 5ms/step
# 1/1 [==============================] - 0s 47ms/step
# 7000/7000 [==============================] - 38s 5ms/step
# 1/1 [==============================] - 0s 47ms/step
# 7000/7000 [==============================] - 38s 5ms/step
# 1/1 [==============================] - 0s 45ms/step
# 7000/7000 [==============================] - 38s 5ms/step
# 1/1 [==============================] - 0s 48ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 46ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 48ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 48ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 46ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 49ms/step
# 7000/7000 [==============================] - 38s 5ms/step
# 1/1 [==============================] - 0s 48ms/step
# 7000/7000 [==============================] - 38s 5ms/step
# 1/1 [==============================] - 0s 46ms/step
# 7000/7000 [==============================] - 38s 5ms/step
# 1/1 [==============================] - 0s 46ms/step
# 7000/7000 [==============================] - 42s 6ms/step
# 1/1 [==============================] - 0s 46ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 47ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 49ms/step
# 7000/7000 [==============================] - 43s 6ms/step
# 1/1 [==============================] - 0s 47ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 48ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 46ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 46ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 49ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 49ms/step
# 7000/7000 [==============================] - 38s 5ms/step
# 1/1 [==============================] - 0s 48ms/step
# 7000/7000 [==============================] - 39s 5ms/step
# 1/1 [==============================] - 0s 46ms/step
# 7000/7000 [==============================] - 39s 5ms/step
# 1/1 [==============================] - 0s 46ms/step
# 7000/7000 [==============================] - 40s 6ms/step
# 1/1 [==============================] - 0s 48ms/step
# 7000/7000 [==============================] - 39s 5ms/step
# 1/1 [==============================] - 0s 47ms/step
# 7000/7000 [==============================] - 39s 5ms/step
# 1/1 [==============================] - 0s 95ms/step
# 7000/7000 [==============================] - 43s 6ms/step
# 1/1 [==============================] - 0s 45ms/step
# 7000/7000 [==============================] - 38s 5ms/step
# 1/1 [==============================] - 0s 47ms/step
# 7000/7000 [==============================] - 38s 5ms/step
# 1/1 [==============================] - 0s 47ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 49ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 47ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 46ms/step
# 7000/7000 [==============================] - 39s 6ms/step
# 1/1 [==============================] - 0s 47ms/step
# 7000/7000 [==============================] - 38s 5ms/step
# 1/1 [==============================] - 0s 46ms/step
# 7000/7000 [==============================] - 39s 5ms/step
# 1/1 [==============================] - 0s 46ms/step
# 7000/7000 [==============================] - 38s 5ms/step

# %%
# plot summary
shap.summary_plot(shap_values, test_features, class_names=["CR", "CRP", "CRT", "CRTP"], plot_size=[8,6], show=False)
plt.savefig("plots/ann/shap_summary_all.png", dpi=600)

# %%
shap.summary_plot(shap_values[0], test_features, plot_size=[8,6], show=False) # summary plot for 'CR' class
plt.savefig("plots/ann/shap_summary_CR.png", dpi=600)

# %%
shap.summary_plot(shap_values[1], test_features, plot_size=[8,6], show=False) # summary plot for 'CRP' class
plt.savefig("plots/ann/shap_summary_CRP.png", dpi=600)

# %%
shap.summary_plot(shap_values[2], test_features, plot_size=[8,6], show=False) # summary plot for 'CRT' class
plt.savefig("plots/ann/shap_summary_CRT.png", dpi=600)

# %%
shap.summary_plot(shap_values[3], test_features, plot_size=[8,6], show=False) # summary plot for 'CRTP' class
plt.savefig("plots/ann/shap_summary_CRTP.png", dpi=600)

# %% [markdown]
# ## Cross Validation

# %%
# Accumulate all the training and test image features and labels
all_features = pd.concat([x_features, test_features], ignore_index=True)
all_labels_enc = np.append(train_labels_enc, test_labels_enc)

# %%
folds = 10
kf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)
acc_per_fold = []

# iterate through each fold
for train_idx, test_idx in kf.split(all_features,  y=all_labels_enc):
    X_train, X_test = all_features.iloc[train_idx], all_features.iloc[test_idx]
    y_train, y_test = all_labels_enc[train_idx], all_labels_enc[test_idx]
    # Fit training data
    ann.fit(X_train, to_categorical(y_train), epochs=150, batch_size=5, verbose=0)
    # Evalute model on test data
    scores = ann.evaluate(X_test, to_categorical(y_test), verbose=0)
    # predict using ann
    y_pred = ann.predict(X_test)
    # get the class with the highest probability
    y_pred_labels = np.argmax(y_pred, axis=1)
    # Calculate accuracy
    acc = accuracy_score(y_test, y_pred_labels)
    acc_per_fold.append(acc)
# Out:
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step

# %%
# Average Accuracy Score
avg_accuracy =  np.mean(acc_per_fold)
print(f'Average Accuracy: {avg_accuracy:.4f}')
# Out:
# Average Accuracy: 0.9571
